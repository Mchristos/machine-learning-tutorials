# %% [markdown]
# # Clustering

# %%
from sklearn.cluster import KMeans 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1D data

# %%
X = np.random.rand(100).reshape(-1,1)
model = KMeans(n_clusters = 4)
model.fit(X)

for i in range(model.labels_.max()+1):
    Xi = X[model.labels_ == i]
    plt.scatter(Xi, np.zeros(len(Xi)))

X.shape
# Out:
# (100, 1)

# %% [markdown]
# ### 2D data
#
# #### Random Data

# %%
n = 1000
X1 = np.random.rand(n)
X2 = np.random.rand(n)
nclusters = [3]

for i, clstrs in enumerate(nclusters):
    model = KMeans(n_clusters = clstrs)
    X = np.array([X1, X2]).reshape(n, 2)
    model.fit(X)
    predictions = model.predict(X)
    # plt.scatter(X[:, 0], X[:, 1], c=predictions, s=50, cmap='viridis')
    plt.scatter(X[:, 0], X[:, 1], c=model.labels_)

# %% [markdown]
# #### Blobs

# %%
from sklearn.datasets.samples_generator import make_blobs
X, y_true = make_blobs(n_samples=300, centers=4,
                       cluster_std=0.60, random_state=0)
plt.scatter(X[:, 0], X[:, 1], s=50);
model = KMeans(n_clusters = 4)
model.fit(X)
plt.figure()
plt.scatter(X[:, 0], X[:, 1], c=model.labels_)
